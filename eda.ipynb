# %% [markdown]
# EDA --> EXPLORATORY DATA ANALYSIS

# %% [markdown]
# Red Wine Dataset

# %%
import pandas as pd

# %%
df = pd.read_csv("winequality-red.csv")

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
# summary of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
# descriptive summary of the dataset
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
df.shape
# Out:
# (1599, 12)

# %%
df["quality"].unique()
# Out:
# array([5, 6, 7, 4, 8, 3])

# %%
# conclusion --> imbalanced dataset
df["quality"].value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
# missing values
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
#checking the duplicate values in dataset
df[df.duplicated()]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4               7.4             0.700         0.00            1.90      0.076
# 11              7.5             0.500         0.36            6.10      0.071
# 27              7.9             0.430         0.21            1.60      0.106
# 40              7.3             0.450         0.36            5.90      0.074
# 65              7.2             0.725         0.05            4.65      0.086
# ...             ...               ...          ...             ...        ...
# 1563            7.2             0.695         0.13            2.00      0.076
# 1564            7.2             0.695         0.13            2.00      0.076
# 1567            7.2             0.695         0.13            2.00      0.076
# 1581            6.2             0.560         0.09            1.70      0.053
# 1596            6.3             0.510         0.13            2.30      0.076
#
# ...

# %%
#removing the duplicate values
df.drop_duplicates(inplace = True)

# %%
df.shape
# Out:
# (1359, 12)

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.255124     0.667437
# volatile acidity          -0.255124          1.000000    -0.551248
# citric acid                0.667437         -0.551248     1.000000
# residual sugar             0.111025         -0.002449     0.143892
# chlorides                  0.085886          0.055154     0.210195
# free sulfur dioxide       -0.140580         -0.020945    -0.048004
# total sulfur dioxide      -0.103777          0.071701     0.047358
# density                    0.670195          0.023943     0.357962
# pH                        -0.686685          0.247111    -0.550310
# sulphates                  0.190269         -0.256948     0.326062
# alcohol                   -0.061596         -0.197812     0.105108
# quality                    0.119024         -0.395214     0.228057
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
## Visualisation

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
plt.figure(figsize=(10,6))

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
df.quality.value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %%
sns.distplot(df["quality"])
# Out:
# <ipython-input-27-41f950265a46>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["quality"])
# <Axes: xlabel='quality', ylabel='Density'>

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
sns.histplot(df["fixed acidity"],kde=True)
# Out:
# <Axes: xlabel='fixed acidity', ylabel='Count'>

# %%
for i in  df.columns:
  sns.histplot(df[i],kde=True)

# %%
# categorical plot

# %%
sns.catplot(x="quality",y="alcohol",data=df,kind="box")

# %%
sns.catplot(x="fixed acidity",y="pH",hue="quality",data=df)

# %% [markdown]
# ## Student Performance Indicator --> EDA

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
df1 = pd.read_csv("stud.csv")

# %%
df1.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df1.shape
# Out:
# (1000, 8)

# %%
#checking the missing values

# %%
df1.isnull().sum()
# Out:
# gender                         0
# race_ethnicity                 0
# parental_level_of_education    0
# lunch                          0
# test_preparation_course        0
# math_score                     0
# reading_score                  0
# writing_score                  0
# dtype: int64

# %%
df1.isna().sum()
# Out:
# gender                         0
# race_ethnicity                 0
# parental_level_of_education    0
# lunch                          0
# test_preparation_course        0
# math_score                     0
# reading_score                  0
# writing_score                  0
# dtype: int64

# %% [markdown]
# ## Insights
# - There are no missing values inside dataset

# %%
#checking the duplicate values

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
#checking the number of unique values of each columns of the dataset

# %%
df1.nunique()
# Out:
# gender                          2
# race_ethnicity                  5
# parental_level_of_education     6
# lunch                           2
# test_preparation_course         2
# math_score                     81
# reading_score                  72
# writing_score                  77
# dtype: int64

# %%
# checking the statistics of the dataset

# %%
df1.describe()
# Out:
#        math_score  reading_score  writing_score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# ## Insights
# - From the above description of the numerical data, all mean are closed to each other between 66 - 69.
# - All standard deviation close to each other between 14.6 to 15.19
# - While there is a minimum values of 0 for maths, others having 17 and 10.

# %%
# Explore more info about data

# %%
df1.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df1.tail()
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
#seggregate the numerical data and categorical data.

# %%
numerical_data = [feature for feature in df1.columns if df1[feature].dtypes!="O"]
categorical_data = [feature for feature in df1.columns if df1[feature].dtypes =="O"]

# %%
numerical_data
# Out:
# ['math_score', 'reading_score', 'writing_score']

# %%
categorical_data
# Out:
# ['gender',
#  'race_ethnicity',
#  'parental_level_of_education',
#  'lunch',
#  'test_preparation_course']

# %%
df1["gender"].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
df1['race_ethnicity'].value_counts()
# Out:
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: race_ethnicity, dtype: int64

# %%
# Agrregate total score with mean

# %%
df1.columns
# Out:
# Index(['gender', 'race_ethnicity', 'parental_level_of_education', 'lunch',
#        'test_preparation_course', 'math_score', 'reading_score',
#        'writing_score'],
#       dtype='object')

# %%
df1["total_sum"]=(df1["math_score"]+df1['reading_score']+df1["writing_score"])
df1["average"]=df1["total_sum"]/3

# %%
df1.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total_sum    average
# 0        218  72.666667
# 1        247  82.333333
# 2        278  92.666667
# 3        148  49.333333
# 4        229  76.333333

# %% [markdown]
# ## VISUALISATION

# %%
fig,axis=plt.subplots(1,2,figsize=(10,5))
plt.subplot(121)
sns.histplot(data=df1,x="average",bins=30,kde=True,color='g')
plt.subplot(122)
sns.histplot(data=df1,x="average",bins=30,kde=True,hue='gender')
# Out:
# <Axes: xlabel='average', ylabel='Count'>

# %% [markdown]
# ## Insights
# - Female student tend to perform well than male students

# %%
plt.subplots(1,3,figsize=(20,5))
plt.subplot(131)
sns.histplot(data=df1,x="average",kde=True,hue="lunch")
plt.subplot(132)
sns.histplot(data=df1[df1.gender=="female"],x="average",kde=True,hue="lunch")
plt.subplot(133)
sns.histplot(data=df1[df1.gender=="male"],x="average",kde=True,hue="lunch")
# Out:
# <Axes: xlabel='average', ylabel='Count'>

# %% [markdown]
# ## Insights
# - Standard Lunch help students perform well in exams
# - Standard lunch helps perform well in exams be it a male of female

# %%
df1.columns
# Out:
# Index(['gender', 'race_ethnicity', 'parental_level_of_education', 'lunch',
#        'test_preparation_course', 'math_score', 'reading_score',
#        'writing_score', 'total_sum', 'average'],
#       dtype='object')

# %%
plt.subplots(1,3,figsize=(20,5))
plt.subplot(131)
sns.histplot(data=df1,x="average",kde=True,hue='parental_level_of_education')
plt.subplot(132)
sns.histplot(data=df1[df1.gender=="female"],x="average",kde=True,hue='parental_level_of_education')
plt.subplot(133)
sns.histplot(data=df1[df1.gender=="male"],x="average",kde=True,hue='parental_level_of_education')
# Out:
# <Axes: xlabel='average', ylabel='Count'>

# %% [markdown]
# #####  Insights
# - In general parent's education don't help student perform well in exam.
# - 3rd plot shows that parent's whose education is of associate's degree or master's degree their male child tend to perform well in exam
# - 2nd plot we can see there is no effect of parent's education on female students.

# %%
plt.subplots(1,3,figsize=(20,5))
plt.subplot(131)
sns.histplot(data=df1,x="average",kde=True,hue='race_ethnicity')
plt.subplot(132)
sns.histplot(data=df1[df1.gender=="female"],x="average",kde=True,hue='race_ethnicity')
plt.subplot(133)
sns.histplot(data=df1[df1.gender=="male"],x="average",kde=True,hue='race_ethnicity')
# Out:
# <Axes: xlabel='average', ylabel='Count'>

# %% [markdown]
# #####  Insights
# - Students of group A and group B tends to perform poorly in exam.
# - Students of group A and group B tends to perform poorly in exam irrespective of whether they are male or female

# %%
sns.heatmap(df1.corr(),annot=True)
# Out:
# <Axes: >
